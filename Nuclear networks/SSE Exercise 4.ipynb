# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def load_history_data(file_path):
    """Load MESA history file with dynamic header parsing."""
    with open(file_path, 'r') as f:
        lines = f.readlines()

    header_line = None
    data_start = None

    for i, line in enumerate(lines):
        if 'star_age' in line and header_line is None:
            header_line = i
        elif header_line is not None and i > header_line:
            data_start = i
            break

    if header_line is None or data_start is None:
        raise ValueError("Header or data section not found in the file.")

    # Extract column headers and load data
    headers = lines[header_line].strip().split()
    df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)
    return df

file_path = "history_1_6_Msol_runnight.data"
df = load_history_data(file_path)

df = df[['star_age', 'log_R']].replace([np.inf, -np.inf], np.nan).dropna()
df['star_age'] = df['star_age'].astype(float)
df['log_R'] = df['log_R'].astype(float)

plt.figure(figsize=(8, 6))
plt.plot(df['star_age'].values, df['log_R'].values, color='royalblue', label='Stellar Radius')
plt.xlabel("Star Age [years]")
plt.ylabel("Radius [$R_\\odot$]")
plt.title("Stellar Radius Evolution Over Time")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21176\477668781.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def load_history_data(file_path):
    """Load MESA history file with dynamic header parsing."""
    with open(file_path, 'r') as f:
        lines = f.readlines()

    header_line = None
    data_start = None

    for i, line in enumerate(lines):
        if 'star_age' in line and header_line is None:
            header_line = i
        elif header_line is not None and i > header_line:
            data_start = i
            break

    if header_line is None or data_start is None:
        raise ValueError("Header or data section not found in the file.")

    headers = lines[header_line].strip().split()
    df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)
    return df

# === Load and process data ===
file_path = "history_exercise_4_1_6.data" 
df = load_history_data(file_path)

# Ensure columns are float for plotting
df = df[['star_age', 'log_R']].replace([np.inf, -np.inf], np.nan).dropna()
df['star_age'] = df['star_age'].astype(float)
df['log_R'] = df['log_R'].astype(float)

plt.figure(figsize=(8, 6))
plt.plot(df['star_age'].values, df['log_R'].values, color='royalblue', label='Stellar Radius')
plt.xlabel("Star Age [years]")
plt.ylabel("Radius [$R_\\odot$]")
plt.title("Stellar Radius Evolution Over Time")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21176\507409602.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def load_history_data(file_path):
    """Load MESA history file with dynamic header parsing."""
    with open(file_path, 'r') as f:
        lines = f.readlines()

    header_line = None
    data_start = None

    for i, line in enumerate(lines):
        if 'star_age' in line and header_line is None:
            header_line = i
        elif header_line is not None and i > header_line:
            data_start = i
            break

    if header_line is None or data_start is None:
        raise ValueError("Header or data section not found in the file.")

    headers = lines[header_line].strip().split()
    df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)
    return df

file1 = "history_1_6_Msol_runnight.data"
file2 = "history_exercise_4_1_6.data"

df1 = load_history_data(file1)
df2 = load_history_data(file2)

# Select and clean the columns
df1 = df1[['star_age', 'log_R']].replace([np.inf, -np.inf], np.nan).dropna()
df2 = df2[['star_age', 'log_R']].replace([np.inf, -np.inf], np.nan).dropna()

# Convert to NumPy arrays (1D)
age1 = df1['star_age'].to_numpy(dtype=float)
radius1 = df1['log_R'].to_numpy(dtype=float)

age2 = df2['star_age'].to_numpy(dtype=float)
radius2 = df2['log_R'].to_numpy(dtype=float)

# === Plot both in one figure ===
plt.figure(figsize=(18, 8))

plt.plot(age1, radius1, label='Exercise 2 (1.6 $M_\\odot$)', color='royalblue', linewidth = 2)
plt.plot(age2, radius2, label='Exercise 4 (1.6 $M_\\odot$)', color='darkorange', linewidth = 2)

plt.xlabel("Star Age [years]")
plt.ylabel("Radius [$R_\\odot$]")
plt.title("Stellar Radius Evolution Over Time")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.xlim(-0.5e6 ,0.5e7)
plt.ylim(0.2,1.75)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21176\621180483.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21176\621180483.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def load_history_data(file_path):
    """Load MESA history file with dynamic header parsing."""
    with open(file_path, 'r') as f:
        lines = f.readlines()

    header_line = None
    data_start = None

    for i, line in enumerate(lines):
        if 'star_age' in line and header_line is None:
            header_line = i
        elif header_line is not None and i > header_line:
            data_start = i
            break

    if header_line is None or data_start is None:
        raise ValueError("Header or data section not found in the file.")

    headers = lines[header_line].strip().split()
    df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)
    return df

file1 = "history_1_6_Msol_runnight.data"
file2 = "history_exercise_4_1_6.data"

df1 = load_history_data(file1)
df2 = load_history_data(file2)

df1 = df1[['star_age', 'log_R']].replace([np.inf, -np.inf], np.nan).dropna()
df2 = df2[['star_age', 'log_R']].replace([np.inf, -np.inf], np.nan).dropna()

age1 = df1['star_age'].to_numpy(dtype=float)
age11 = np.log10(age1) 
radius1 = df1['log_R'].to_numpy(dtype=float)

age2 = df2['star_age'].to_numpy(dtype=float)
age22 = np.log10(age2)
radius2 = df2['log_R'].to_numpy(dtype=float)

plt.figure(figsize=(18, 8))

plt.plot(age1, radius1, label='Exercise 2 (1.6 $M_\\odot$)', color='royalblue', linewidth = 15, alpha = 0.4)
plt.plot(age2, radius2, label='Exercise 4 (1.6 $M_\\odot$)', color='red', linewidth = 4)

plt.xlabel("Star Age [years]", fontsize = 18)
plt.ylabel("Radius [$R_\\odot$]", fontsize = 18)
plt.title("Stellar Radius Evolution Over Time", fontsize = 22)
plt.legend(fontsize = 18)
plt.grid(False)
plt.tight_layout()
plt.tick_params(axis='both', which='major', labelsize=20)
#plt.xlim(-0.5e6 ,0.5e7)
#plt.ylim(0.2,1.75)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_592\3748555962.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_592\3748555962.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def load_history_data(file_path):
    """Load MESA history file with dynamic header parsing."""
    with open(file_path, 'r') as f:
        lines = f.readlines()

    header_line = None
    data_start = None

    for i, line in enumerate(lines):
        if 'star_age' in line and header_line is None:
            header_line = i
        elif header_line is not None and i > header_line:
            data_start = i
            break

    if header_line is None or data_start is None:
        raise ValueError("Header or data section not found in the file.")

    headers = lines[header_line].strip().split()
    df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)
    return df

file1 = "history_1_6_Msol_runnight.data"
file2 = "history_exercise_4_1_6.data"

df1 = load_history_data(file1)
df2 = load_history_data(file2)

df1 = df1[['star_age', 'log_R']].replace([np.inf, -np.inf], np.nan).dropna()
df2 = df2[['star_age', 'log_R']].replace([np.inf, -np.inf], np.nan).dropna()

age1 = df1['star_age'].to_numpy(dtype=float)
age11 = np.log10(age1) 
radius1 = df1['log_R'].to_numpy(dtype=float)

age2 = df2['star_age'].to_numpy(dtype=float)
age22 = np.log10(age2)
radius2 = df2['log_R'].to_numpy(dtype=float)

plt.figure(figsize=(18, 8))

plt.plot(age1, radius1, label='Exercise 2 (1.6 $M_\\odot$)', color='royalblue', linewidth = 4, alpha = 0.5)
plt.plot(age2, radius2, label='Exercise 4 (1.6 $M_\\odot$)', color='red', linewidth = 4)

plt.xlabel("Star Age [years]", fontsize = 18)
plt.ylabel("Radius [$R_\\odot$]", fontsize = 18)
plt.title("Stellar Radius Evolution Over Time", fontsize = 22)
plt.legend(fontsize = 18)
plt.grid(False)
plt.tight_layout()
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlim(-100000 ,0.9e6)
plt.ylim(0.4,1.75)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_592\1713089015.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_592\1713089015.py:24: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

def load_history_data(file_path):
    """Load MESA history file with dynamic header parsing."""
    with open(file_path, 'r') as f:
        lines = f.readlines()

    header_line = None
    data_start = None

    for i, line in enumerate(lines):
        if 'star_age' in line and header_line is None:
            header_line = i
        elif header_line is not None and i > header_line:
            data_start = i
            break

    if header_line is None or data_start is None:
        raise ValueError("Header or data section not found in the file.")

    headers = lines[header_line].strip().split()
    df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)
    return df

file1 = "history_1_6_Msol_runnight.data"
file2 = "history_exercise_4_1_6.data"

df1 = load_history_data(file1)
df2 = load_history_data(file2)

df1 = df1[['star_age', 'log_R']].replace([np.inf, -np.inf], np.nan).dropna()
df2 = df2[['star_age', 'log_R']].replace([np.inf, -np.inf], np.nan).dropna()

age1 = df1['star_age'].to_numpy(dtype=float)
radius1 = df1['log_R'].to_numpy(dtype=float)

age2 = df2['star_age'].to_numpy(dtype=float)
radius2 = df2['log_R'].to_numpy(dtype=float)

fig, ax = plt.subplots(figsize=(14, 7))

ax.plot(age1, radius1, label='Exercise 2 (1.6 $M_\\odot$)', color='royalblue', linewidth=10, alpha=0.5)
ax.plot(age2, radius2, label='Exercise 4 (1.6 $M_\\odot$)', color='red', linewidth=4)

ax.set_xlabel("Star Age [years]", fontsize=16)
ax.set_ylabel("Radius [$R_\\odot$]", fontsize=16)
ax.set_title("Stellar Radius Evolution with Zoom-In", fontsize=20)
ax.legend(fontsize=14)
ax.tick_params(axis='both', which='major', labelsize=14)

axins = inset_axes(ax, width="50%", height="50%", loc="center", borderpad=3)

axins.plot(age1, radius1, color='blue', linewidth=1.5, alpha=0.9)
axins.plot(age2, radius2, color='red', linewidth=1.5)

x1, x2 = -100000, 0.6e6
y1, y2 = 0.5, 1.75
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
axins.tick_params(axis='both', which='major', labelsize=10)

mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec="black", lw=1.5)

plt.tight_layout()
plt.savefig("ex_4_q2.jpg", dpi = 1200)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_592\1680646683.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_592\1680646683.py:25: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_592\1680646683.py:76: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def load_history_data(file_path):
    """Robust loader for MESA history.data file."""
    with open(file_path, 'r') as f:
        lines = f.readlines()

    header_line = None
    data_start = None

    for i, line in enumerate(lines):
        if "star_age" in line and header_line is None:
            header_line = i
        if header_line is not None and i > header_line:
            data_start = i
            break

    if header_line is None or data_start is None:
        raise ValueError("Header or data start not found.")

    headers = lines[header_line].strip().split()
    df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)
    return df

file_path = "history_1_6_Msol_runnight.data"
df = load_history_data(file_path)

pre_ms_df = df[df['log_center_T'] < 7]

pre_ms_df = pre_ms_df[['star_age', 'log_R']].replace([np.inf, -np.inf], np.nan).dropna()
pre_ms_df['star_age'] = pre_ms_df['star_age'].astype(float)
pre_ms_df['log_R'] = pre_ms_df['log_R'].astype(float)

plt.figure(figsize=(8, 6))
plt.plot(pre_ms_df['star_age'].values, pre_ms_df['log_R'].values, label='Radius (Pre-MS)', color='darkgreen')
plt.xlabel("Star Age [years]")
plt.ylabel("Radius [$R_\\odot$]")
plt.title("Pre-Main Sequence Radius Evolution")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def load_history_data(file_path):
    """Robust loader for MESA history.data file."""
    with open(file_path, 'r') as f:
        lines = f.readlines()

    header_line = None
    data_start = None

    for i, line in enumerate(lines):
        if "star_age" in line and header_line is None:
            header_line = i
        if header_line is not None and i > header_line:
            data_start = i
            break

    if header_line is None or data_start is None:
        raise ValueError("Header or data start not found.")

    headers = lines[header_line].strip().split()
    df = pd.read_csv(file_path, skiprows=data_start, delim_whitespace=True, names=headers)
    return df

file_path = "history_exercise_4_1_6.data"
df = load_history_data(file_path)

pre_ms_df = df[df['log_center_T'] < 7]

pre_ms_df = pre_ms_df[['star_age', 'log_R']].replace([np.inf, -np.inf], np.nan).dropna()
pre_ms_df['star_age'] = pre_ms_df['star_age'].astype(float)
pre_ms_df['log_R'] = pre_ms_df['log_R'].astype(float)

plt.figure(figsize=(8, 6))
plt.plot(pre_ms_df['star_age'].values, pre_ms_df['log_R'].values, label='Radius (Pre-MS)', color='darkgreen')
plt.xlabel("Star Age [years]")
plt.ylabel("Radius [$R_\\odot$]")
plt.title("Pre-Main Sequence Radius Evolution")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def load_history_data(file_path):
    """Loads a MESA history.data file into a DataFrame."""
    with open(file_path, 'r') as f:
        lines = f.readlines()

    for i, line in enumerate(lines):
        if line.strip().startswith("model_number"):
            col_names = line.strip().split()
            start_data = i + 1
            break
    else:
        raise ValueError("Could not find the column header in the file.")

    df = pd.read_csv(file_path, skiprows=start_data, delim_whitespace=True, names=col_names)

    df.columns = df.columns.str.strip()

    return df

file_path = "history_exercise_4_1_6.data"
df = load_history_data(file_path)

df_prems = df[np.array(df["center_he4"]) < 0.3].copy()


plt.figure(figsize=(10, 6))
plt.plot(np.array(df_prems["star_age"]), np.array(df_prems["log_R"]), label="Pre-MS Radius", color='teal')

plt.xlabel("Stellar Age (Myr)")
plt.ylabel("Radius ($R_\\odot$)")
plt.title("Pre-Main Sequence Radius Evolution")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21176\744792488.py:20: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=start_data, delim_whitespace=True, names=col_names)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def load_history_data(file_path):
    """Loads a MESA history.data file into a DataFrame."""
    with open(file_path, 'r') as f:
        lines = f.readlines()

    for i, line in enumerate(lines):
        if line.strip().startswith("model_number"):
            col_names = line.strip().split()
            start_data = i + 1
            break
    else:
        raise ValueError("Could not find the column header in the file.")

    df = pd.read_csv(file_path, skiprows=start_data, delim_whitespace=True, names=col_names)

    df.columns = df.columns.str.strip()

    return df

file_path = "history_exercise_4_1_6.data"
df = load_history_data(file_path)

df_prems = df[np.array(df["center_he4"]) < 0.5].copy() 

plt.figure(figsize=(10, 6))
plt.plot(np.array(df_prems["star_age"]), np.array(df_prems["log_R"]), label="Pre-MS Radius", color='teal')

plt.xlabel("Stellar Age (Myr)")
plt.ylabel("Radius ($R_\\odot$)")
plt.title("Pre-Main Sequence Radius Evolution")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21176\3952548976.py:20: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=start_data, delim_whitespace=True, names=col_names)

# %% [markdown]
# # Question 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

with open("profile3.data", "r") as f:
    lines = f.readlines()

for i, line in enumerate(lines):
    if line.strip().startswith("zone"):
        header_line = i
        break

columns = lines[header_line].strip().split()
data_lines = lines[header_line + 1:]

df = pd.read_csv(StringIO("".join(data_lines)), delim_whitespace=True, names=columns)

df["convective"] = df["gradr"] > df["grada"]

q = df["q"].to_numpy()
gradr = df["gradr"].to_numpy()
grada = df["grada"].to_numpy()
convective_mask = df["convective"].to_numpy()

# Plot
plt.figure(figsize=(10, 6))
plt.plot(q, gradr, label="∇rad (gradr)", color="red")
plt.plot(q, grada, label="∇ad (grada)", color="blue")
plt.fill_between(q, gradr, grada, where=convective_mask, color="orange", alpha=0.3, label="Convective Zone")

plt.xlabel("Relative Mass Coordinate (q)", fontsize = 16)
plt.ylabel("Temperature Gradients", fontsize = 16)
plt.title("Convective Region at TAMS", fontsize = 20)
plt.legend(fontsize = 15)
plt.grid(False)
plt.tight_layout()
plt.tick_params(axis='both', which='major', labelsize=15)

plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1680\2879769943.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO("".join(data_lines)), delim_whitespace=True, names=columns)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

with open("profile6.data", "r") as f:
    lines = f.readlines()

for i, line in enumerate(lines):
    if line.strip().startswith("zone"):
        header_line = i
        break

columns = lines[header_line].strip().split()
data_lines = lines[header_line + 1:]

df = pd.read_csv(StringIO("".join(data_lines)), delim_whitespace=True, names=columns)

df["convective"] = df["gradr"] > df["grada"]

q = df["q"].to_numpy()
logt = df['logT'].to_numpy()
gradr = df["gradr"].to_numpy()
grada = df["grada"].to_numpy()
convective_mask = df["convective"].to_numpy()

plt.figure(figsize=(10, 6))
plt.plot(q, gradr, label="∇rad (gradr)", color="red")
plt.plot(q, grada, label="∇ad (grada)", color="blue")
plt.fill_between(q, gradr, grada, where=convective_mask, color="orange", alpha=0.3, label="Convective Zone")

plt.xlabel("Relative Mass Coordinate (q)", fontsize = 16)
plt.ylabel("Temperature Gradients", fontsize = 16)
plt.title("Convective Region at profile 6", fontsize = 20)
plt.legend(fontsize = 15)
plt.grid(False)
plt.tight_layout()
plt.tick_params(axis='both', which='major', labelsize=15)

plt.savefig("ex_4_fig_final.jpg", dpi = 1200)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9280\3650092176.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO("".join(data_lines)), delim_whitespace=True, names=columns)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

with open("profile3.data", "r") as f:
    lines = f.readlines()

for i, line in enumerate(lines):
    if line.strip().startswith("zone"):
        header_line = i
        break

columns = lines[header_line].strip().split()
data_lines = lines[header_line + 1:]

df = pd.read_csv(StringIO("".join(data_lines)), delim_whitespace=True, names=columns)

df["convective"] = df["gradr"] > df["grada"]

q = df["q"].to_numpy()
logt = df['logT'].to_numpy()
gradr = df["gradr"].to_numpy()
grada = df["grada"].to_numpy()
convective_mask = df["convective"].to_numpy()


plt.figure(figsize=(10, 6))
plt.plot(q, logt, label="Relation at model 300, profile 3", color="red")
plt.axhline(y=6, color='b', linestyle='--', label = 'Burning at $1 x 10^6$ K for $^2$H')

plt.xlabel("Relative Mass Coordinate (q)", fontsize = 16)
plt.ylabel("Temperature (log))", fontsize = 16)
plt.title("Relative mass and relation with log of temperature", fontsize = 20)
plt.legend(fontsize = 15)
plt.grid(False)
plt.tight_layout()
plt.tick_params(axis='both', which='major', labelsize=15)

plt.savefig("ex_4_q3_1.jpg", dpi = 1200)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1680\1262404935.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO("".join(data_lines)), delim_whitespace=True, names=columns)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

with open("profile4.data", "r") as f:
    lines = f.readlines()

for i, line in enumerate(lines):
    if line.strip().startswith("zone"):
        header_line = i
        break

columns = lines[header_line].strip().split()
data_lines = lines[header_line + 1:]

df = pd.read_csv(StringIO("".join(data_lines)), delim_whitespace=True, names=columns)

df["convective"] = df["gradr"] > df["grada"]

q = df["q"].to_numpy()
logt = df['logT'].to_numpy()
gradr = df["gradr"].to_numpy()
grada = df["grada"].to_numpy()
convective_mask = df["convective"].to_numpy()


plt.figure(figsize=(10, 6))
plt.plot(q, logt, label="Relation at model 400, profile 4", color="red")
plt.axhline(y=6, color='b', linestyle='--', label = 'Burning at $1 x 10^6$ K for $^2$H')

plt.xlabel("Relative Mass Coordinate (q)", fontsize = 16)
plt.ylabel("Temperature (log)", fontsize = 16)
plt.title("Relative mass and relation with log of temperature", fontsize = 20)
plt.legend(fontsize = 15)
plt.grid(False)
plt.tight_layout()
plt.tick_params(axis='both', which='major', labelsize=15)

plt.savefig("ex_4_q3_2.jpg", dpi = 1200)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1680\1079359604.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO("".join(data_lines)), delim_whitespace=True, names=columns)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

with open("profile5.data", "r") as f:
    lines = f.readlines()

for i, line in enumerate(lines):
    if line.strip().startswith("zone"):
        header_line = i
        break

columns = lines[header_line].strip().split()
data_lines = lines[header_line + 1:]

df = pd.read_csv(StringIO("".join(data_lines)), delim_whitespace=True, names=columns)

df["convective"] = df["gradr"] > df["grada"]

q = df["q"].to_numpy()
logt = df['logT'].to_numpy()
gradr = df["gradr"].to_numpy()
grada = df["grada"].to_numpy()
convective_mask = df["convective"].to_numpy()



plt.figure(figsize=(10, 6))
plt.plot(q, logt, label="Relation at model 500, profile 5", color="black")
plt.axhline(y=6, color='b', linestyle='--', label = 'Burning at $1 x 10^6$ K for $^2$H')
plt.axhline(y=6.3010299957, color='purple', linestyle='--', label = 'Burning at $2 x 10^6$ K for $^2$H (Other universe)')

plt.xlabel("Relative Mass Coordinate (q)", fontsize = 16)
plt.ylabel("Temperature(Log)", fontsize = 16)
plt.title("Relative mass and relation with log of temperature", fontsize = 20)
plt.legend(fontsize = 15)
plt.grid(False)
plt.tight_layout()
plt.tick_params(axis='both', which='major', labelsize=15)

plt.savefig("ex_4_q4_1.jpg", dpi = 1200)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1680\2259873910.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO("".join(data_lines)), delim_whitespace=True, names=columns)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

with open("profile6.data", "r") as f:
    lines = f.readlines()

for i, line in enumerate(lines):
    if line.strip().startswith("zone"):
        header_line = i
        break

columns = lines[header_line].strip().split()
data_lines = lines[header_line + 1:]

df = pd.read_csv(StringIO("".join(data_lines)), delim_whitespace=True, names=columns)

df["convective"] = df["gradr"] > df["grada"]

q = df["q"].to_numpy()
logt = df['logT'].to_numpy()
gradr = df["gradr"].to_numpy()
grada = df["grada"].to_numpy()
convective_mask = df["convective"].to_numpy()


plt.figure(figsize=(10, 6))
plt.plot(q, logt, label="Relation at model 600, profile 6", color="black")
plt.axhline(y=6, color='b', linestyle='--', label = 'Burning at $1 x 10^6$ K for $^2$H')
plt.axhline(y=6.3010299957, color='purple', linestyle='--', label = 'Burning at $2 x 10^6$ K for $^2$H (Other universe)')

plt.xlabel("Relative Mass Coordinate (q)", fontsize = 16)
plt.ylabel("Temperature Gradients", fontsize = 16)
plt.title("Relative mass and relation with log of temperature", fontsize = 20)
plt.legend(fontsize = 15)
plt.grid(False)
plt.tight_layout()
plt.tick_params(axis='both', which='major', labelsize=15)

plt.savefig("ex_4_q4_1.jpg", dpi = 1200)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1680\406382060.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO("".join(data_lines)), delim_whitespace=True, names=columns)
